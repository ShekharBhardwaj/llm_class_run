# %% [markdown]
# # 🤖 Diving Deeper: Tokenizers & Lower-Level Hugging Face APIs
#
# ---
# <img src="../token.png" width="500" height="500"/>
# ## 🎯 What We're Learning In this Lab?
#
# - Move **beyond Pipelines** and into **lower-level APIs**!
# - Understand **Tokenizers**: how AI models "read" text.
# - Learn about **Chat Templates**: how conversations get turned into tokens.
#
# ---
#
# ## 🧠 What is a Tokenizer?
#
# - A **Tokenizer** converts **text** into **tokens** (numbers!) and back.
# - Think of it as a **text shredder and builder**:
#   - **Encode**: `"Hello!"` ➔ `[1542, 312, 29]`
#   - **Decode**: `[1542, 312, 29]` ➔ `"Hello!"`
#
# ✅ Every model needs a tokenizer to work properly.
#
# ✅ Each model usually has its **own tokenizer** (because they were trained together).
#
# ---
#
# ## 🔥 Special Tokens
#
# - Some tokens have **special meanings** like:
#   - `<start>` ➔ Beginning of a sentence
#   - `<user>` ➔ Start of a user message
#   - `<assistant>` ➔ Start of an assistant response
#
# ✅ Models **learn** what these tokens mean by seeing them during training —
# there's no magic, just lots of examples!
#
# ---
#
# ## 💬 What is a Chat Template?
#
# - It's a **recipe** for turning multi-turn conversations into a single token list.
# - E.g., combining system, user, and assistant messages into one long stream of tokens.
#
# ✅ Hugging Face tokenizers for chat models (like LLaMA, Phi, Qwen) use templates.
#
# ---
#
# ## 🔥 Models We’ll Explore
#
# | Model | What's Cool About It |
# |:---|:---|
# | **Llama 3.1** (Meta) | Open-source game-changer |
# | **Phi 3** (Microsoft) | Tiny but mighty model |
# | **Qwen 2** (Alibaba) | Fluent in English & Chinese |
# | **StarCoder 2** | Specialized for generating code! |
#
# ---
#
# # 🎯 Final Thought
#
# > **Pipelines are magic wands. Tokenizers are the secret spells.** 🪄
# > Today you become true AI sorcerers — ready to control the text universe!
# > **Tokenizers:** https://colab.research.google.com/drive/1Q-YaD4sWes5napwL5voTYpmqRv4M7ssE?usp=sharing
